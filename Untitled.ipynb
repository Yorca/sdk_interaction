# %%
from androguard.misc import AnalyzeAPK
import androguard.core.analysis.analysis

a, d, dx = AnalyzeAPK("/Users/yorca/Downloads/KawaiiWorld-CraftandBuild_1.5.2_Apkpure.apk")
# Out:
# 2024-04-10 17:34:21.154 | DEBUG    | androguard.misc:AnalyzeAPK:41 - AnalyzeAPK
# 2024-04-10 17:34:21.155 | DEBUG    | androguard.misc:AnalyzeAPK:56 - Analysing without session
# 2024-04-10 17:34:21.237 | INFO     | androguard.core.apk:_apk_analysis:312 - Starting analysis on AndroidManifest.xml
# 2024-04-10 17:34:21.239 | DEBUG    | androguard.core.axml:__init__:940 - AXMLPrinter
# 2024-04-10 17:34:21.239 | DEBUG    | androguard.core.axml:__init__:375 - AXMLParser
# 2024-04-10 17:34:21.241 | DEBUG    | androguard.core.axml:__init__:399 - FIRST HEADER <ARSCHeader idx='0x00000000' type='3' header_size='8' size='54212'>
# 2024-04-10 17:34:21.242 | DEBUG    | androguard.core.axml:__init__:439 - STRING_POOL <ARSCHeader idx='0x00000008' type='1' header_size='28' size='26512'>
# 2024-04-10 17:34:21.243 | DEBUG    | androguard.core.axml:is_valid:466 - True
# 2024-04-10 17:34:21.244 | DEBUG    | androguard.core.axml:_do_next:484 - M_EVENT -1
# ...
